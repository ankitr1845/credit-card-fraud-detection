# %% [markdown]
# # Hello

# %% [markdown]
# ## Tutorial

# %%
print(1)
print("Ankit")
# Out:
# 1
# Ankit

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
n = np.array((3,1,2))
print(n)
# Out:
# [3 1 2]

# %%
print(type(n))
# Out:
# <class 'numpy.ndarray'>

# %%
import pandas as pd

# %%
x = np.array([0,4])
y = np.array([0, 50])
plt.plot(x,y)
plt.show()

# %%
pwd
# Out:
# 'C:\\Users\\coola\\Desktop\\Untitled Folder'
